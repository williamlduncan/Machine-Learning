# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from distutils.version import LooseVersion
from scipy.stats import norm
from sklearn.neighbors import KernelDensity

# %%
# `normed` is being deprecated in favor of `density` in histograms
if LooseVersion(matplotlib.__version__) >= '2.1':
    density_param = {'density': True}
else:
    density_param = {'normed': True}

# %%
for axi in ax.ravel():
    axi.plot(X[:, 0], np.full(X.shape[0], -0.01), '+k')
    axi.set_xlim(-4, 9)
    axi.set_ylim(-0.02, 0.34)

for axi in ax[:, 0]:
    axi.set_ylabel('Normalized Density')

for axi in ax[1, :]:
    axi.set_xlabel('x')

# %%
#----------------------------------------------------------------------
# Plot the progression of histograms to kernels
np.random.seed(1)
N = 20
X = np.concatenate((np.random.normal(0, 1, int(0.3 * N)),
                    np.random.normal(5, 1, int(0.7 * N))))[:, np.newaxis]
X_plot = np.linspace(-5, 10, 1000)[:, np.newaxis]
bins = np.linspace(-5, 10, 10)

fig, ax = plt.subplots(2, 2, sharex=True, sharey=True)
fig.subplots_adjust(hspace=0.05, wspace=0.05)
# histogram 1
ax[0, 0].hist(X[:, 0], bins=bins, fc='#AAAAFF', **density_param)
ax[0, 0].text(-3.5, 0.31, "Histogram")
# histogram 2
ax[0, 1].hist(X[:, 0], bins=bins + 0.75, fc='#AAAAFF', **density_param)
ax[0, 1].text(-3.5, 0.31, "Histogram, bins shifted")
# tophat KDE
kde = KernelDensity(kernel='tophat', bandwidth=0.75).fit(X)
log_dens = kde.score_samples(X_plot)
ax[1, 0].fill(X_plot[:, 0], np.exp(log_dens), fc='#AAAAFF')
ax[1, 0].text(-3.5, 0.31, "Tophat Kernel Density")
# Gaussian KDE
kde = KernelDensity(kernel='gaussian', bandwidth=0.75).fit(X)
log_dens = kde.score_samples(X_plot)
ax[1, 1].fill(X_plot[:, 0], np.exp(log_dens), fc='#AAAAFF')
ax[1, 1].text(-3.5, 0.31, "Gaussian Kernel Density")
# Out:
# Text(-3.5, 0.31, 'Gaussian Kernel Density')

# %%
#----------------------------------------------------------------------
# Plot all available kernels
X_plot = np.linspace(-6, 6, 1000)[:, None]
X_src = np.zeros((1, 1))

fig, ax = plt.subplots(2, 3, sharex=True, sharey=True)
fig.subplots_adjust(left=0.05, right=0.95, hspace=0.05, wspace=0.05)


def format_func(x, loc):
    if x == 0:
        return '0'
    elif x == 1:
        return 'h'
    elif x == -1:
        return '-h'
    else:
        return '%ih' % x

for i, kernel in enumerate(['gaussian', 'tophat', 'epanechnikov',
                            'exponential', 'linear', 'cosine']):
    axi = ax.ravel()[i]
    log_dens = KernelDensity(kernel=kernel).fit(X_src).score_samples(X_plot)
    axi.fill(X_plot[:, 0], np.exp(log_dens), '-k', fc='#AAAAFF')
    axi.text(-2.6, 0.95, kernel)

    axi.xaxis.set_major_formatter(plt.FuncFormatter(format_func))
    axi.xaxis.set_major_locator(plt.MultipleLocator(1))
    axi.yaxis.set_major_locator(plt.NullLocator())

    axi.set_ylim(0, 1.05)
    axi.set_xlim(-2.9, 2.9)

ax[0, 1].set_title('Available Kernels')
# Out:
# Text(0.5, 1.0, 'Available Kernels')

# %%
excel_file = 'census income.xlsx'
X = pd.read_excel(excel_file)

# %%
X.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K

# %%
sorted = X.sort_values(['fnlwgt'])

# %%
sorted["fnlwgt"].head(10)
# Out:
# 19115    12285
# 27908    13769
# 26634    14878
# 25156    18827
# 13658    19214
# 3972     19302
# 28280    19302
# 6087     19302
# 18836    19302
# 2573     19302
# Name: fnlwgt, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sorted['fnlwgt'].head(10).plot(kind="barh")
plt.show()

# %%
X.drop(['workclass', 'education', 'marital.status', 'occupation', 'relationship', 'race', 'sex', 'native.country', 'income'], axis=1)
# Out:
#        age  fnlwgt  education.num  capital.gain  capital.loss  hours.per.week
# 0       90   77053              9             0          4356              40
# 1       82  132870              9             0          4356              18
# 2       66  186061             10             0          4356              40
# 3       54  140359              4             0          3900              40
# 4       41  264663             10             0          3900              40
# 5       34  216864              9             0          3770              45
# 6       38  150601              6             0          3770              40
# 7       74   88638             16             0          3683              20
# 8       68  422013              9             0          3683              40
# 9       41   70037             10             0          3004              60
# 10      45  172274             16             0          3004              35
# 11      38  164526             15             0          2824              45
# 12      52  129177             13             0          2824              20
# 13      32  136204             14             0          2824              55
# 14      51  172175             16             0          2824              40
# 15      46   45363             15             0          2824              40
# 16      45  172822              7             0          2824              76
# 17      57  317847             14             0          2824              50
# 18      22  119592             12             0          2824              40
# 19      34  203034             13             0          2824              50
# 20      37  188774             13             0          2824              40
# 21      29   77009              7             0          2754              42
# 22      61   29059              9             0          2754              25
# 23      51  153870             10             0          2603              40
# 24      61  135285              9             0          2603              32
# 25      21   34310             11             0          2603              40
# 26      33  228696              2             0          2603              32
# 27      49  122066              3             0          2603              40
# 28      37  107164              6             0          2559              50
# 29      38  175360              6             0          2559              90
# ...    ...     ...            ...           ...           ...             ...
# 32531   31  292592              9             0             0              40
# 32532   29  125976              9             0             0              35
# 32533   35  320084             13             0             0              55
# 32534   30   33811             13             0             0              99
# 32535   34  204461             16             0             0              60
# 32536   54  337992             13             0             0              50
# 32537   37  179137             10             0             0              39
# 32538   22  325033              8             0             0              35
# 32539   34  160216             13             0             0              55
# 32540   30  345898              9             0             0              46
# 32541   71  287372             16             0             0              10
# 32542   45  252208              9             0             0              40
# 32543   41  202822              9             0             0              32
# 32544   72  129912              9             0             0              25
# 32545   45  119199             12             0             0              48
# 32546   31  199655             14             0             0              30
# 32547   39  111499             12             0             0              20
# 32548   37  198216             12             0             0              40
# 32549   43  260761              9             0             0              40
# 32550   43  255835             10             0             0              40
# 32551   43   27242             10             0             0              50
# 32552   32   34066              6             0             0              40
# 32553   43   84661             11             0             0              45
# 32554   32  116138             14             0             0              11
# 32555   53  321865             14             0             0              40
# 32556   22  310152             10             0             0              40
# 32557   27  257302             12             0             0              38
# 32558   40  154374              9             0             0              40
# 32559   58  151910              9             0             0              40
# 32560   22  201490              9             0             0              20
#
# [32561 rows x 6 columns]

# %%
#----------------------------------------------------------------------
# Plot a 1D density example
#N = 100
#np.random.seed(1)
#X = np.concatenate((np.random.normal(0, 1, int(0.3 * N)),
#                    np.random.normal(5, 1, int(0.7 * N))))[:, np.newaxis]

df = pd.read_excel('census income.xlsx')
X=[]
X.append(df['fnlwgt'])
#X_plot = np.linspace(-5, 10, 1000)[:, np.newaxis]

true_dens = (0.3 * norm(0, 1).pdf(X_plot[:, 0])
             + 0.7 * norm(5, 1).pdf(X_plot[:, 0]))

fig, ax = plt.subplots()
ax.fill(X_plot[:, 0], true_dens, fc='black', alpha=0.2,
        label='input distribution')

for kernel in ['gaussian', 'tophat', 'epanechnikov']:
    kde = KernelDensity(kernel=kernel, bandwidth=0.5).fit(X)
    log_dens = kde.score_samples(X_plot)
    ax.plot(X_plot[:, 0], np.exp(log_dens), '-',
            label="kernel = '{0}'".format(kernel))

ax.text(6, 0.38, "N={0} points".format(N))

ax.legend(loc='upper left')
ax.plot(X[:, 0], -0.005 - 0.01 * np.random.random(X.shape[0]), '+k')

ax.set_xlim(-4, 9)
ax.set_ylim(-0.02, 0.4)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-e4b36f8dc008> in <module>
#      20 for kernel in ['gaussian', 'tophat', 'epanechnikov']:
#      21     kde = KernelDensity(kernel=kernel, bandwidth=0.5).fit(X)
# ---> 22     log_dens = kde.score_samples(X_plot)
#      23     ax.plot(X_plot[:, 0], np.exp(log_dens), '-',
#      24             label="kernel = '{0}'".format(kernel))
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/kde.py in score_samples(self, X)
#     175         log_density = self.tree_.kernel_density(
#     176             X, h=self.bandwidth, kernel=self.kernel, atol=atol_N,
# --> 177             rtol=self.rtol, breadth_first=self.breadth_first, return_log=True)
#     178         log_density -= np.log(N)
#     179         return log_density
#
# sklearn/neighbors/binary_tree.pxi in sklearn.neighbors.kd_tree.BinaryTree.kernel_density()
#
# ValueError: query data dimension must match training data dimension
